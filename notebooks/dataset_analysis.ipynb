# %%
from pathlib import Path

import pandas as pd
import seaborn as sns

import requests

# %%
ROOT = Path("/Users/zhursvlevy/Desktop/master/NLP/PostProcessor/PostProcessor")

# %%
data = pd.read_parquet(ROOT / "data" / "pikabu" / "0000.parquet")

# %%
data.head()
# Out:
#         id                                              title  \
# 0  6991642  Что можно купить в Китае за цену нового iPhone...
# 1  7178566  Последний оставшийся в живых освободитель Осве...
# 2  7021067                              Зима в Тюмень пришла.
# 3  7041076                                        Доброе утро
# 4  7177157           Есть такая в черноземье сеть пиццерий...
#
#                                        text_markdown   timestamp  author_id  \
# 0  Осенью в России стартовали продажи очередной м...  1571221527    2900955
# 1  В канун 75-летия освобождения концлагеря и V В...  1579586602    1723707
# 2  И в честь этого я сочинил свой первый пирожок....  1572537738    2473821
# 3                                                     1573533861     648409
# 4  В общем, если в кратце, то заказал я как-то пе...  1579522525    2488762
#
#          username  rating  pluses  minuses  \
# 0   chinatoday.ru      -4       9       13
# 1          sssr24    1339    1498      159
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23000 entries, 0 to 22999
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             23000 non-null  int64
#  1   title          23000 non-null  object
#  2   text_markdown  23000 non-null  object
#  3   timestamp      23000 non-null  uint64
#  4   author_id      23000 non-null  int64
#  5   username       23000 non-null  object
#  6   rating         23000 non-null  int64
#  7   pluses         23000 non-null  int64
#  8   minuses        23000 non-null  int64
#  9   url            23000 non-null  object
#  10  tags           23000 non-null  object
#  11  blocks         23000 non-null  object
#  12  comments       23000 non-null  object
# dtypes: int64(5), object(7), uint64(1)
# memory usage: 2.3+ MB
